# %%
# !pip install wrf-python
# !pip install cython
# !pip install wheel cartopy
# !pip install xarray
# !pip install pykdtree
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wrf-python in ./.local/lib/python3.9/site-packages (1.3.1)
# Requirement already satisfied: wrapt in ./.local/lib/python3.9/site-packages (from wrf-python) (1.12.1)
# Requirement already satisfied: setuptools in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from wrf-python) (49.6.0.post20210108)
# Requirement already satisfied: numpy>=1.11 in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from wrf-python) (1.20.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cython in ./.local/lib/python3.9/site-packages (0.29.23)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wheel in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (0.36.2)
# Requirement already satisfied: cartopy in ./.local/lib/python3.9/site-packages (0.19.0.post1)
# Requirement already satisfied: shapely>=1.5.6 in ./.local/lib/python3.9/site-packages (from cartopy) (1.7.1)
# Requirement already satisfied: numpy>=1.13.3 in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from cartopy) (1.20.2)
# Requirement already satisfied: pyshp>=2 in ./.local/lib/python3.9/site-packages (from cartopy) (2.1.3)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xarray in ./.local/lib/python3.9/site-packages (0.18.2)
# Requirement already satisfied: numpy>=1.17 in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from xarray) (1.20.2)
# Requirement already satisfied: setuptools>=40.4 in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from xarray) (49.6.0.post20210108)
# Requirement already satisfied: pandas>=1.0 in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from xarray) (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from pandas>=1.0->xarray) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from pandas>=1.0->xarray) (2021.1)
# Requirement already satisfied: six>=1.5 in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->xarray) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pykdtree
#   Downloading pykdtree-1.3.4-cp39-cp39-manylinux1_x86_64.whl (210 kB)
#      |████████████████████████████████| 210 kB 3.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/ohpc/pub/apps/miniconda/4.8.3/envs/wrfda/lib/python3.9/site-packages (from pykdtree) (1.20.2)
# Installing collected packages: pykdtree
# Successfully installed pykdtree-1.3.4

# %%
from os import system
import numpy as np

import matplotlib.animation as animation
import matplotlib.pyplot as plt

import cartopy.crs as ccrs

from IPython.display import HTML
from netCDF4 import Dataset
from wrf import getvar, interplevel, to_np, latlon_coords

# %%
nc = Dataset('/work/syseng/wrfda_2021-06-03-22.50.04/m1')
for v in nc.variables:
    print(v)
# Out:
# Times
# XLAT
# XLONG
# LU_INDEX
# ZNU
# ZNW
# ZS
# DZS
# VAR_SSO
# U
# V
# W
# PH
# PHB
# T
# THM
# HFX_FORCE
# LH_FORCE
# TSK_FORCE
# HFX_FORCE_TEND
# LH_FORCE_TEND
# TSK_FORCE_TEND
# MU
# MUB
# NEST_POS
# P
# PB
# FNM
# FNP
# RDNW
# RDN
# DNW
# DN
# CFN
# CFN1
# THIS_IS_AN_IDEAL_RUN
# P_HYD
# Q2
# T2
# TH2
# PSFC
# U10
# V10
# RDX
# RDY
# AREA2D
# DX2D
# RESM
# ZETATOP
# CF1
# CF2
# CF3
# ITIMESTEP
# XTIME
# QVAPOR
# QCLOUD
# QRAIN
# QICE
# QSNOW
# QGRAUP
# SHDMAX
# SHDMIN
# SNOALB
# TSLB
# SMOIS
# SH2O
# SMCREL
# SEAICE
# XICEM
# SFROFF
# UDROFF
# IVGTYP
# ISLTYP
# VEGFRA
# GRDFLX
# ACGRDFLX
# ACSNOM
# SNOW
# SNOWH
# CANWAT
# SSTSK
# COSZEN
# LAI
# DTAUX3D
# DTAUY3D
# DUSFCG
# DVSFCG
# VAR
# CON
# OA1
# OA2
# OA3
# OA4
# OL1
# OL2
# OL3
# OL4
# MAPFAC_M
# MAPFAC_U
# MAPFAC_V
# MAPFAC_MX
# MAPFAC_MY
# MAPFAC_UX
# MAPFAC_UY
# MAPFAC_VX
# MF_VX_INV
# MAPFAC_VY
# F
# E
# SINALPHA
# COSALPHA
# HGT
# TSK
# P_TOP
# T00
# P00
# TLP
# TISO
# TLP_STRAT
# P_STRAT
# MAX_MSTFX
# MAX_MSTFY
# RAINC
# RAINSH
# RAINNC
# SNOWNC
# GRAUPELNC
# HAILNC
# CLDFRA
# SWDOWN
# GLW
# SWNORM
# ACSWUPT
# ACSWUPTC
# ACSWDNT
# ACSWDNTC
# ACSWUPB
# ACSWUPBC
# ACSWDNB
# ACSWDNBC
# ACLWUPT
# ACLWUPTC
# ACLWDNT
# ACLWDNTC
# ACLWUPB
# ACLWUPBC
# ACLWDNB
# ACLWDNBC
# SWUPT
# SWUPTC
# SWDNT
# SWDNTC
# SWUPB
# SWUPBC
# SWDNB
# SWDNBC
# LWUPT
# LWUPTC
# LWDNT
# LWDNTC
# LWUPB
# LWUPBC
# LWDNB
# LWDNBC
# OLR
# XLAT_U
# XLONG_U
# XLAT_V
# XLONG_V
# ALBEDO
# CLAT
# ALBBCK
# EMISS
# NOAHRES
# TMN
# XLAND
# UST
# PBLH
# HFX
# QFX
# LH
# ACHFX
# ACLHF
# SNOWC
# SR
# SAVE_TOPO_FROM_REAL
# ISEEDARR_SPPT
# ISEEDARR_SKEBS
# ISEEDARR_RAND_PERTURB
# ISEEDARRAY_SPP_CONV
# ISEEDARRAY_SPP_PBL
# ISEEDARRAY_SPP_LSM
# C1H
# C2H
# C1F
# C2F
# C3H
# C4H
# C3F
# C4F
# PCB
# PC
# LANDMASK
# LAKEMASK
# SST
# SST_INPUT

# %%
def get_wind_data(data: Dataset, t: int, z: int):
    z *= 1000
    height = getvar(data, "HGT", timeidx=t)
    u_all = getvar(data, 'U', units="m s-1", timeidx=t)
    v_all = getvar(data, 'V', units="m s-1", timeidx=t)
    w_all = getvar(data, 'W', units="m s-1", timeidx=t)
    u = interplevel(u_all, height, z)
    v = interplevel(v_all, height, z)
    w = interplevel(w_all, height, z)
    
    return u, v, np.sqrt(u**2+v**2+w**2)

# %%
crs = ccrs.PlateCarree()
cmap = plt.get_cmap('plasma')
lon = (-77, -75)
lat = (10, 12)

fig = plt.figure(figsize=(20, 12))
ax = fig.add_subplot(111, facecolor='None', projection=crs)
ax.coastlines(resolution='10m')
#ax.set_xlim(lon)
#ax.set_ylim(lat)

u, v, mag = get_wind_data(nc, t=1, z=6)
lats, lons = latlon_coords(u)
plot = ax.pcolormesh(lons, lats, mag, cmap=cmap)
cbar = fig.colorbar(plot)
cbar.ax.set_ylabel('Wind speed (m/s)', fontsize=20)
cbar.ax.tick_params(labelsize=20)

gl = ax.gridlines(crs=crs, draw_labels=True, alpha=0.5)
gl.xlabel_style = {'size': 20, 'color': 'black'}
gl.ylabel_style = {'size': 20, 'color': 'black'}
gl.top_labels = None
gl.right_labels = None

def init():
    plot.set_array(np.array([]))
    return plot,

def update(i):
    u, v, mag = get_wind_data(nc, i, 6)
    plot.set_array(mag)
    return plot,
i=0
update(i)
plt.savefig(f'img_{str(i).zfill(4)}.png', dpi=40, bbox_inches='tight', pad_inches=0)
plt.gca()

system("convert -delay 40 -loop 0 img_*.png sacc/src/assets/forecast/visualization.gif && rm img_*")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1d59a7265fbe> in <module>
#      10 #ax.set_ylim(lat)
#      11
# ---> 12 u, v, mag = get_wind_data(nc, t=1, z=6)
#      13 lats, lons = latlon_coords(u)
#      14 plot = ax.pcolormesh(lons, lats, mag, cmap=cmap)
#
# <ipython-input-5-9bbcab2ae524> in get_wind_data(data, t, z)
#       2     z *= 1000
#       3     height = getvar(data, "HGT", timeidx=t)
# ----> 4     u_all = getvar(data, 'U', units="m s-1", timeidx=t)
#       5     v_all = getvar(data, 'V', units="m s-1", timeidx=t)
#       6     w_all = getvar(data, 'W', units="m s-1", timeidx=t)
#
# ~/.local/lib/python3.9/site-packages/wrf/routines.py in getvar(wrfin, varname, timeidx, method, squeeze, cache, meta, **kwargs)
#     333
#     334     if is_standard_wrf_var(wrfin, varname) and varname != "Times":
# --> 335         _check_kargs("default", kwargs)
#     336         return extract_vars(wrfin, timeidx, varname,
#     337                             method, squeeze, cache, meta, _key)[varname]
#
# ~/.local/lib/python3.9/site-packages/wrf/routines.py in _check_kargs(var, kargs)
#     216                           "argument for '{}'".format(arg, var))
#     217             else:
# --> 218                 raise ValueError("'{}' is an invalid keyword "
#     219                                  "argument".format(arg))
#     220
#
# ValueError: 'units' is an invalid keyword argument
# /home/syseng/sjdonado/.local/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/10m/physical/ne_10m_coastline.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
"""plt.close(fig)
anim = animation.FuncAnimation(fig, update, frames=24, blit=True, repeat=False, init_func=init)
dpi = 100
writer = animation.writers['ffmpeg'](fps=5)
anim.save('test.mp4',writer=writer,dpi=dpi)"""
#HTML(anim.to_jshtml())
# Out:
# "plt.close(fig)\nanim = animation.FuncAnimation(fig, update, frames=24, blit=True, repeat=False, init_func=init)\ndpi = 100\nwriter = animation.writers['ffmpeg'](fps=5)\nanim.save('test.mp4',writer=writer,dpi=dpi)"
