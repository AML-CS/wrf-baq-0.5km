# %%
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs

from IPython.display import HTML
from netCDF4 import Dataset
from os import system
from wrf import getvar, interplevel, to_np, latlon_coords
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-99e9749a99b1> in <module>
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 4 import cartopy.crs as ccrs
#       5
#       6 from IPython.display import HTML
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
def get_wind_data(data: Dataset, t: int, z: int):
    z *= 1000
    height = getvar(data, "height", timeidx=t)
    u_all = getvar(data, 'ua', units="m s-1", timeidx=t)
    v_all = getvar(data, 'va', units="m s-1", timeidx=t)
    w_all = getvar(data, 'wa', units="m s-1", timeidx=t)
    u = interplevel(u_all, height, z)
    v = interplevel(v_all, height, z)
    w = interplevel(w_all, height, z)
    
    return u, v, np.sqrt(u**2+v**2+w**2)

# %%
nc = Dataset('forecast2')

crs = ccrs.PlateCarree()
cmap = plt.get_cmap('plasma')
lon = (-87, -70)
lat = (5, 18)

fig = plt.figure(figsize=(20, 12))
ax = fig.add_subplot(111, facecolor='None', projection=crs)
ax.coastlines(resolution='10m')
#ax.set_xlim(lon)
#ax.set_ylim(lat)

u, v, mag = get_wind_data(nc, t=1, z=6)
lats, lons = latlon_coords(u)
plot = ax.pcolormesh(lons, lats, mag, cmap=cmap)
cbar = fig.colorbar(plot)
cbar.ax.set_ylabel('Wind speed (m/s)', fontsize=20)
cbar.ax.tick_params(labelsize=20)

gl = ax.gridlines(crs=crs, draw_labels=True, alpha=0.5)
gl.xlabel_style = {'size': 20, 'color': 'black'}
gl.ylabel_style = {'size': 20, 'color': 'black'}
gl.top_labels = None
gl.right_labels = None

def init():
    plot.set_array(np.array([]))
    return plot,

def update(i):
    u, v, mag = get_wind_data(nc, i, 6)
    plot.set_array(mag)
    return plot,

for i in range(24):
    update(i)
    plt.savefig(f'img_{str(i).zfill(4)}.png', dpi=40, bbox_inches='tight', pad_inches=0)
    plt.gca()
    
system("convert -delay 40 -loop 0 img_*.png sacc/src/assets/forecast/visualization.gif && rm img_*")
# Out:
# /home/dan/.anaconda/lib/python3.8/site-packages/cartopy/mpl/geoaxes.py:1598: UserWarning: The input coordinates to pcolormesh are interpreted as cell centers, but are not monotonically increasing or decreasing. This may lead to incorrectly calculated cell edges, in which case, please supply explicit cell edges to pcolormesh.
#   X, Y, C, shading = self._pcolorargs('pcolormesh', *args,
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-12cf347d4adc> in <module>
#      35
#      36 for i in range(24):
# ---> 37     update(i)
#      38     plt.savefig(f'img_{str(i).zfill(4)}.png', dpi=40, bbox_inches='tight', pad_inches=0)
#      39     plt.gca()
#
# <ipython-input-13-12cf347d4adc> in update(i)
#      30
#      31 def update(i):
# ---> 32     u, v, mag = get_wind_data(nc, i, 6)
#      33     plot.set_array(mag)
#      34     return plot,
#
# <ipython-input-11-7a064cea2ecb> in get_wind_data(data, t, z)
#       1 def get_wind_data(data: Dataset, t: int, z: int):
#       2     z *= 1000
# ----> 3     height = getvar(data, "height", timeidx=t)
#       4     u_all = getvar(data, 'ua', units="m s-1", timeidx=t)
#       5     v_all = getvar(data, 'va', units="m s-1", timeidx=t)
#
# ~/.anaconda/lib/python3.8/site-packages/wrf/routines.py in getvar(wrfin, varname, timeidx, method, squeeze, cache, meta, **kwargs)
#     352     _check_kargs(actual_var, kwargs)
#     353
# --> 354     return _FUNC_MAP[actual_var](wrfin, timeidx, method, squeeze, cache,
#     355                                  meta, _key, **kwargs)
#
# ~/.anaconda/lib/python3.8/site-packages/wrf/metadecorators.py in func_wrapper(wrapped, instance, args, kwargs)
#     706             is_met_em = True
#     707
# --> 708         ht_var = extract_vars(wrfin, timeidx, ht_metadata_varname,
#     709                               method, squeeze, cache, meta=True,
#     710                               _key=_key)
#
# ~/.anaconda/lib/python3.8/site-packages/wrf/util.py in extract_vars(wrfin, timeidx, varnames, method, squeeze, cache, meta, _key)
#    2287         varlist = varnames
#    2288
# -> 2289     return {var: _extract_var(wrfin, var, timeidx, None,
#    2290                               method, squeeze, cache, meta, _key)
#    2291             for var in varlist}
#
# ~/.anaconda/lib/python3.8/site-packages/wrf/util.py in <dictcomp>(.0)
#    2287         varlist = varnames
#    2288
# -> 2289     return {var: _extract_var(wrfin, var, timeidx, None,
#    2290                               method, squeeze, cache, meta, _key)
#    2291             for var in varlist}
#
# ~/.anaconda/lib/python3.8/site-packages/wrf/util.py in _extract_var(wrfin, varname, timeidx, is_moving, method, squeeze, cache, meta, _key)
#    2214             if is_moving is None:
#    2215                 is_moving = is_moving_domain(wrfin, varname, _key=_key)
# -> 2216             result = _build_data_array(wrfin, varname, timeidx, is_moving,
#    2217                                        multifile, _key)
#    2218         else:
#
# ~/.anaconda/lib/python3.8/site-packages/wrf/util.py in _build_data_array(wrfnc, varname, timeidx, is_moving_domain, is_multifile, _key)
#    1253     var = wrfnc.variables[varname]
#    1254     if len(var.shape) > 1:
# -> 1255         data = var[time_idx_or_slice, :]
#    1256     else:
#    1257         data = var[time_idx_or_slice]
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable.__getitem__()
#
# src/netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Variable._get()
#
# IndexError: index exceeds dimension bounds

# %%
"""plt.close(fig)
anim = animation.FuncAnimation(fig, update, frames=24, blit=True, repeat=False, init_func=init)
dpi = 100
writer = animation.writers['ffmpeg'](fps=5)
anim.save('test.mp4',writer=writer,dpi=dpi)"""
#HTML(anim.to_jshtml())
# Out:
# "plt.close(fig)\nanim = animation.FuncAnimation(fig, update, frames=24, blit=True, repeat=False, init_func=init)\ndpi = 100\nwriter = animation.writers['ffmpeg'](fps=5)\nanim.save('test.mp4',writer=writer,dpi=dpi)"
